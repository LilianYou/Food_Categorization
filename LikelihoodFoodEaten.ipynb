# %% [markdown]
# Author: Betty van Dongen. Oct. 11th, 2020

# %%
import s3fs
import pandas as pd

# csv file
df = pd.read_json('s3://sagemaker-studio-528576943967-ssf9zkrg3os/train.json')

# %%
len(df)
# Out:
# 39774

# %%
df
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
# https://stackoverflow.com/questions/50217968/pandas-split-list-in-column-into-multiple-rows
new_df = pd.DataFrame([
    [p, t, i] for p, t, I in df.values
    for i in I
], columns=df.columns)

# %%
new_new_df = new_df.drop(columns=['cuisine'])
# Out:
#            id  cuisine      ingredients
# 0       10259    greek  romaine lettuce
# 1       10259    greek     black olives
# 2       10259    greek   grape tomatoes
# 3       10259    greek           garlic
# 4       10259    greek           pepper
# ...       ...      ...              ...
# 428270   2362  mexican           garlic
# 428271   2362  mexican      white sugar
# 428272   2362  mexican    roma tomatoes
# 428273   2362  mexican           celery
# 428274   2362  mexican    dried oregano
#
# [428275 rows x 3 columns]

# %%
new_new_df
# Out:
#            id      ingredients
# 0       10259  romaine lettuce
# 1       10259     black olives
# 2       10259   grape tomatoes
# 3       10259           garlic
# 4       10259           pepper
# ...       ...              ...
# 428270   2362           garlic
# 428271   2362      white sugar
# 428272   2362    roma tomatoes
# 428273   2362           celery
# 428274   2362    dried oregano
#
# [428275 rows x 2 columns]

# %%
ingredients_list = new_new_df['ingredients'].tolist()

# %%
ingredients_list
# Out:
# ['romaine lettuce',
#  'black olives',
#  'grape tomatoes',
#  'garlic',
#  'pepper',
#  'purple onion',
#  'seasoning',
#  'garbanzo beans',
#  'feta cheese crumbles',
#  'plain flour',
#  'ground pepper',
#  'salt',
#  'tomatoes',
#  'ground black pepper',
#  'thyme',
#  'eggs',
#  'green tomatoes',
#  'yellow corn meal',
#  'milk',
#  'vegetable oil',
#  'eggs',
#  'pepper',
#  'salt',
#  'mayonaise',
#  'cooking oil',
#  'green chilies',
#  'grilled chicken breasts',
#  'garlic powder',
#  'yellow onion',
#  'soy sauce',
#  'butter',
#  'chicken livers',
#  'water',
#  'vegetable oil',
#  'wheat',
#  'salt',
#  'black pepper',
#  'shallots',
#  'cornflour',
#  'cayenne pepper',
#  'onions',
#  'garlic paste',
#  'milk',
#  'butter',
#  'salt',
#  'lemon juice',
#  'water',
#  'chili powder',
#  'passata',
#  'oil',
#  'ground cumin',
#  'boneless chicken skinless thigh',
#  'garam masala',
#  'double cream',
#  'natural yogurt',
#  'bay leaf',
#  'plain flour',
#  'sugar',
# ...

# %%
def relative_frequency(lst, element):
    return lst.count(element) / float(len(lst)) 

# words = ['apple', 'banana', 'apple', 'orange'] 
print(relative_frequency(ingredients_list, 'oil'))
# Out:
# 0.004599848228357947

# %%
counts = [(word, ingredients_list.count(word) / len(ingredients_list)) for word in set(ingredients_list)]

# %%
counts
# Out:
# [('stewing hen', 9.339793357071974e-06),
#  ('cold cut', 9.339793357071974e-06),
#  ('raw pistachios', 9.339793357071974e-06),
#  ('spinach tortilla', 2.3349483392679936e-06),
#  ('gluten-free spaghetti', 4.669896678535987e-06),
#  ('millet', 1.167474169633997e-05),
#  ('wide rice noodles', 4.669896678535988e-05),
#  ('sodium free chicken stock', 2.3349483392679936e-06),
#  ('orange marmalade', 9.806783024925573e-05),
#  ('mojo marinade', 2.3349483392679936e-06),
#  ('tuna', 0.00010273772692779173),
#  ('chunky tomatoes', 2.3349483392679936e-06),
#  ('unflavored gelatin', 0.00025217442064094333),
#  ('chocolate truffle', 4.669896678535987e-06),
#  ('skinned boned duck breast halves', 2.3349483392679936e-06),
#  ('oyster liquor', 2.3349483392679936e-06),
#  ('dukkah', 4.669896678535987e-06),
#  ('plain low-fat yogurt', 0.00011674741696339968),
#  ('wish bone red wine vinaigrett dress', 2.3349483392679936e-06),
#  ('bottled low sodium salsa', 2.3349483392679936e-06),
# ...
